# %% [markdown]
# Bismillahirrahmanirrahiiim bisaaa lancarrr dan diberi petunjuk aaamiiin

# %% [markdown]
# # MultiModal Target Sentiment Analysis - Google Maps Restaurant Reviews

# %% [markdown]
# ## Import Library

# %% [markdown]
# ### Install transformers

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 94.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
import transformers
from transformers import(
    BertModel,
    BertTokenizer,
    AdamW,
    get_linear_schedule_with_warmup
)
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from collections import defaultdict
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import json
import random

# %%
from transformers import logging
logging.set_verbosity_error()

# %% [markdown]
# ## Permission to Mydrive

# %%
# mount gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Data

# %%
parent_path = "/content/drive/My Drive/Bismillah_Skripsi_Bisa_Amiiin/Final_Data/"
path_v1 = parent_path + "v1_with_stemming/"
path_v2 = parent_path + "v2_without_stemming/"
path_v1_revisi = parent_path + "v1_version_with_stemming_revisi/"
path_v2_revisi = parent_path + "v2_version_without_stemming_revisi/"
path_v2_revisi2 = parent_path + "v2_version_without_stemming_revisi2/"
path_v3 = parent_path + "v3_version_with_stemming_without_stopword/"
path_v3_revisi = parent_path + "v3_version_with_stemming_without_stopword_revisi/"
path_v4 = parent_path + "v4_version_without_stemming_without_stopword/"
path_v4_revisi = parent_path + "v4_version_without_stopwords_without_stemming/"

# %%
parent_captions_path = "/content/drive/My Drive/Bismillah_Skripsi_Bisa_Amiiin/captions/"
indo_captions = parent_captions_path + "indonesia/"
eng_captions = parent_captions_path + "english/"

## sub folder path english caption
base_coco = eng_captions + 'base_coco/'
large_coco = eng_captions + 'large_coco/'
# path_captions_v1 = parent_captions_path + "v1_with_stemming/"
# path_captions_v2 = parent_captions_path + "v2_without_stemming/"
# path_captions_v1_revisi = parent_captions_path + "v1_version_with_stemming_revisi/"
# path_captions_v2_revisi = parent_captions_path + "v2_version_without_stemming_revisi/"
# path_captions_v2_revisi2 = parent_captions_path + "v2_version_without_stemming_revisi2/"
# path_captions_v3 = parent_captions_path + "v3_version_with_stemming_without_stopword/"
# path_captions_v3_revisi = parent_captions_path + "v3_version_with_stemming_without_stopword_revisi/"
# path_captions_v4 = parent_captions_path + "v4_version_without_stemming_without_stopword/"
# path_captions_v4_revisi = parent_captions_path + "v4_version_without_stopwords_without_stemming/"

# %%
# train_data = "/content/drive/My Drive/absa_data/twitter2015/test.tsv"
# dev_data = "/content/drive/My Drive/absa_data/twitter2015/test.tsv"
# test_data = "/content/drive/My Drive/absa_data/twitter2015/test.tsv"
path_data = path_v3_revisi
train_data = path_data + "train.xlsx"
dev_data = path_data + "validation.xlsx"
test_data = path_data + "test.xlsx"
captions_json = indo_captions + "captions.json"

# HYPER PARAMETER
PRE_TRAINED_MODEL_NAME = "bert-base-multilingual-uncased"
MAX_LEN = 350
BATCH_SIZE = 16
DROPOUT_PROB = 0.08745593824742746
NUM_CLASSES = 3
DEVICE = "cuda:1"
EPOCHS = 10
LEARNING_RATE = 1.2713600123715536e-05
ADAMW_CORRECT_BIAS = True
NUM_WARMUP_STEPS = 0
NUM_RUNS = 1
# RANDOM_SEEDS = list(range(NUM_RUNS))
# # # # # # # # # # # # # # # # # # # # #

# %%
spek_model = str(PRE_TRAINED_MODEL_NAME)+'_'+'lr_'+str(LEARNING_RATE)+'_dropout_'+str(DROPOUT_PROB)
result_train_file_name = 'results_train_per_run_' + spek_model + '.json'
result_test_file_name = 'results_test_per_run_' + spek_model + '.json'
model_name = 'trained_model_' + spek_model + '.pth'
# path_file_drive = 'content/drive/My Drive/Bismillah_Skripsi_Bisa_Amiiin/Running/' + result_file_name

print('spek model : ',spek_model)
print('result train file name : ',result_train_file_name)
print('result test file name : ',result_test_file_name)
print('model name : ', model_name)
# print('path_file_drive : ',path_file_drive)
# Out:
# spek model :  bert-base-multilingual-uncased_lr_1.2713600123715536e-05_dropout_0.08745593824742746
# result train file name :  results_train_per_run_bert-base-multilingual-uncased_lr_1.2713600123715536e-05_dropout_0.08745593824742746.json
# result test file name :  results_test_per_run_bert-base-multilingual-uncased_lr_1.2713600123715536e-05_dropout_0.08745593824742746.json
# model name :  trained_model_bert-base-multilingual-uncased_lr_1.2713600123715536e-05_dropout_0.08745593824742746.pth

# %% [markdown]
# ## Load and Messages the Dataframes

# %%
train_df = pd.read_excel(train_data)
dev_df = pd.read_excel(dev_data)
test_df = pd.read_excel(test_data)

# %%
#drop column with index 0 by index
train_df.drop(train_df.columns[[0]], axis=1, inplace=True)

# %%
#drop column with index 0 by index
dev_df.drop(dev_df.columns[[0]], axis=1, inplace=True)

# %%
#drop column with index 0 by index
test_df.drop(test_df.columns[[0]], axis=1, inplace=True)

# %%
# Checking train dataframes
train_df.info()
train_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2160 non-null   object
#  1   review_img_url  2160 non-null   object
#  2   review_rating   2160 non-null   int64
#  3   review_text     2160 non-null   object
#  4   review_date     2160 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 84.5+ KB
#                                name  \
# 0  Bebek Tepi Sawah Restaurant Ubud
# 1  Bebek Tepi Sawah Restaurant Ubud
# 2  Bebek Tepi Sawah Restaurant Ubud
# 3         Grand Garden Resto & Cafe
# 4           Koenokoeni Cafe Gallery
#
#                                       review_img_url  review_rating  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPgsL...              2
# 1  https://lh5.googleusercontent.com/p/AF1QipOiXB...              2
# 2  https://lh5.googleusercontent.com/p/AF1QipPiO2...              2
# 3  https://lh5.googleusercontent.com/p/AF1QipOhLM...              2
# 4  https://lh5.googleusercontent.com/p/AF1QipMJKP...              2
#
#                                          review_text review_date
# 0  tempat luas juga bersih untuk makan cukup enak...  2022-09-24
# 1  suasana yang sejuk dan asri tambah nafsu makan...  2022-03-14
# 2  ramai enak cuma entah kenapa ga seeenak dulu p...  2022-04-23
# 3  nuansa taman dari rumah klasik dengan banyak p...  2019-06-27
# 4  various menu dapat welcome drink jamu dan snac...  2022-09-22

# %%
# Checking validation dataframes
dev_df.info()
dev_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            270 non-null    object
#  1   review_img_url  270 non-null    object
#  2   review_rating   270 non-null    int64
#  3   review_text     270 non-null    object
#  4   review_date     270 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 10.7+ KB
#                                            name  \
# 0           Kampung Daun Culture Gallery & Cafe
# 1                     Sekar Kedhaton Restaurant
# 2                                Konro Karebosi
# 3                             Gudeg Bu Hj. Amad
# 4  Sindang Reret Restaurant & Catering Karawang
#
#                                       review_img_url  review_rating  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPYY3...              0
# 1  https://lh5.googleusercontent.com/p/AF1QipMLaL...              0
# 2  https://lh5.googleusercontent.com/p/AF1QipMcD4...              0
# 3  https://lh5.googleusercontent.com/p/AF1QipPKaD...              0
# 4  https://lh5.googleusercontent.com/p/AF1QipMMDT...              0
#
#                                          review_text review_date
# 0  meski buka dengan prokes ketat tempat ini luma...  2021-10-22
# 1  pesan yang catat salah tunggu sangat lama bisa...  2022-05-12
# 2  maaf banget harus kasih bintang tapi jujur kec...  2021-11-12
# 3          gudeg enak kerupuk enak telur enak banget  2017-03-28
# 4  dapat nasi tutuk oncom kasih bonus lalat maaf ...  2021-01-10

# %%
# Checking validation dataframes
test_df.info()
test_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            270 non-null    object
#  1   review_img_url  270 non-null    object
#  2   review_rating   270 non-null    int64
#  3   review_text     270 non-null    object
#  4   review_date     270 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 10.7+ KB
#                                            name  \
# 0                       Koenokoeni Cafe Gallery
# 1                         Pesta Keboen Restoran
# 2  Sindang Reret Restaurant & Catering Karawang
# 3                                  Bebek Bengil
# 4                        Gabah Restaurant & Bar
#
#                                       review_img_url  review_rating  \
# 0  https://lh3.googleusercontent.com/a-/ACNPEu-ee...              0
# 1  https://lh3.googleusercontent.com/a-/ACNPEu8iA...              0
# 2  https://lh5.googleusercontent.com/p/AF1QipP4yf...              0
# 3  https://lh5.googleusercontent.com/p/AF1QipP8td...              0
# 4  https://lh5.googleusercontent.com/p/AF1QipPZyg...              0
#
#                                          review_text review_date
# 0  pertama kali kesini niat hati ingin jamu tamu ...  2022-06-24
# 1  layan kurang ramah masakan biasa saja tidak pu...  2020-09-15
# 2  restoran sunda turun dan hanya itu cara seluru...  2019-02-21
# 3  bebek krispy dan ga minyak tapi rasa biasa saj...  2022-02-24
# 4  kami dapat batu di makan kami tidak ada kembal...  2018-02-24

# %% [markdown]
# ## Rename Column in each dataframes

# %%
# Rename column name of train_df dataframes
train_df = train_df.rename(
    {
        "review_rating": "sentiment",
        "name": "target",
        "review_img_url": "image_url",
    },
    axis=1,
)

# %%
train_df.head()
# Out:
#                              target  \
# 0  Bebek Tepi Sawah Restaurant Ubud
# 1  Bebek Tepi Sawah Restaurant Ubud
# 2  Bebek Tepi Sawah Restaurant Ubud
# 3         Grand Garden Resto & Cafe
# 4           Koenokoeni Cafe Gallery
#
#                                            image_url  sentiment  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPgsL...          2
# 1  https://lh5.googleusercontent.com/p/AF1QipOiXB...          2
# 2  https://lh5.googleusercontent.com/p/AF1QipPiO2...          2
# 3  https://lh5.googleusercontent.com/p/AF1QipOhLM...          2
# 4  https://lh5.googleusercontent.com/p/AF1QipMJKP...          2
#
#                                          review_text review_date
# 0  tempat luas juga bersih untuk makan cukup enak...  2022-09-24
# 1  suasana yang sejuk dan asri tambah nafsu makan...  2022-03-14
# 2  ramai enak cuma entah kenapa ga seeenak dulu p...  2022-04-23
# 3  nuansa taman dari rumah klasik dengan banyak p...  2019-06-27
# 4  various menu dapat welcome drink jamu dan snac...  2022-09-22

# %%
# Rename column name of val_df dataframes
val_df = dev_df.rename(
    {
        "review_rating": "sentiment",
        "name": "target",
        "review_img_url": "image_url",
    },
    axis=1,
)

# %%
val_df.head()
# Out:
#                                          target  \
# 0           Kampung Daun Culture Gallery & Cafe
# 1                     Sekar Kedhaton Restaurant
# 2                                Konro Karebosi
# 3                             Gudeg Bu Hj. Amad
# 4  Sindang Reret Restaurant & Catering Karawang
#
#                                            image_url  sentiment  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPYY3...          0
# 1  https://lh5.googleusercontent.com/p/AF1QipMLaL...          0
# 2  https://lh5.googleusercontent.com/p/AF1QipMcD4...          0
# 3  https://lh5.googleusercontent.com/p/AF1QipPKaD...          0
# 4  https://lh5.googleusercontent.com/p/AF1QipMMDT...          0
#
#                                          review_text review_date
# 0  meski buka dengan prokes ketat tempat ini luma...  2021-10-22
# 1  pesan yang catat salah tunggu sangat lama bisa...  2022-05-12
# 2  maaf banget harus kasih bintang tapi jujur kec...  2021-11-12
# 3          gudeg enak kerupuk enak telur enak banget  2017-03-28
# 4  dapat nasi tutuk oncom kasih bonus lalat maaf ...  2021-01-10

# %%
# Rename column name of test_df dataframes
test_df = test_df.rename(
    {
        "review_rating": "sentiment",
        "name": "target",
        "review_img_url": "image_url",
    },
    axis=1,
)

# %%
test_df.head()
# Out:
#                                          target  \
# 0                       Koenokoeni Cafe Gallery
# 1                         Pesta Keboen Restoran
# 2  Sindang Reret Restaurant & Catering Karawang
# 3                                  Bebek Bengil
# 4                        Gabah Restaurant & Bar
#
#                                            image_url  sentiment  \
# 0  https://lh3.googleusercontent.com/a-/ACNPEu-ee...          0
# 1  https://lh3.googleusercontent.com/a-/ACNPEu8iA...          0
# 2  https://lh5.googleusercontent.com/p/AF1QipP4yf...          0
# 3  https://lh5.googleusercontent.com/p/AF1QipP8td...          0
# 4  https://lh5.googleusercontent.com/p/AF1QipPZyg...          0
#
#                                          review_text review_date
# 0  pertama kali kesini niat hati ingin jamu tamu ...  2022-06-24
# 1  layan kurang ramah masakan biasa saja tidak pu...  2020-09-15
# 2  restoran sunda turun dan hanya itu cara seluru...  2019-02-21
# 3  bebek krispy dan ga minyak tapi rasa biasa saj...  2022-02-24
# 4  kami dapat batu di makan kami tidak ada kembal...  2018-02-24

# %%
# Checking train_df dataframes
train_df
# Out:
#                                                  target  \
# 0                      Bebek Tepi Sawah Restaurant Ubud
# 1                      Bebek Tepi Sawah Restaurant Ubud
# 2                      Bebek Tepi Sawah Restaurant Ubud
# 3                             Grand Garden Resto & Cafe
# 4                               Koenokoeni Cafe Gallery
# ...                                                 ...
# 2155                                      The Holy Crab
# 2156  Taman Santap Rumah Kayu - Summarecon Gading Se...
# 2157  Taman Santap Rumah Kayu - Summarecon Gading Se...
# 2158                                        Seafood Ayu
# 2159                                        Seafood Ayu
#
#                                               image_url  sentiment  \
# 0     https://lh5.googleusercontent.com/p/AF1QipPgsL...          2
# 1     https://lh5.googleusercontent.com/p/AF1QipOiXB...          2
# 2     https://lh5.googleusercontent.com/p/AF1QipPiO2...          2
# 3     https://lh5.googleusercontent.com/p/AF1QipOhLM...          2
# 4     https://lh5.googleusercontent.com/p/AF1QipMJKP...          2
# ...                                                 ...        ...
# 2155  https://lh5.googleusercontent.com/p/AF1QipM_s2...          0
# 2156  https://lh5.googleusercontent.com/p/AF1QipMfSa...          0
# 2157  https://lh5.googleusercontent.com/p/AF1QipPM-E...          0
# 2158  https://lh5.googleusercontent.com/p/AF1QipOpB3...          0
# 2159  https://lh5.googleusercontent.com/p/AF1QipMHG3...          0
#
#                                             review_text review_date
# 0     tempat luas juga bersih untuk makan cukup enak...  2022-09-24
# 1     suasana yang sejuk dan asri tambah nafsu makan...  2022-03-14
# 2     ramai enak cuma entah kenapa ga seeenak dulu p...  2022-04-23
# 3     nuansa taman dari rumah klasik dengan banyak p...  2019-06-27
# 4     various menu dapat welcome drink jamu dan snac...  2022-09-22
# ...                                                 ...         ...
# 2155  mahal dengan selera yang sangat buruk layan he...  2018-09-30
# 2156  makan di rumah makan ini harus penuh sabar jan...  2022-04-08
# 2157  suasana bagus hanya saja terlalu banyak anak k...  2023-01-21
# 2158  ramai ini restoran sudah makin ga manusiawi da...  2018-10-30
# 2159            ramai banget ojek online tidak rekomend  2019-02-17
#
# [2160 rows x 5 columns]

# %%
# Checking val_df dataframes
val_df
# Out:
#                                            target  \
# 0             Kampung Daun Culture Gallery & Cafe
# 1                       Sekar Kedhaton Restaurant
# 2                                  Konro Karebosi
# 3                               Gudeg Bu Hj. Amad
# 4    Sindang Reret Restaurant & Catering Karawang
# ..                                            ...
# 265                            tuna house Megamas
# 266                           Kepiting Cak Gundul
# 267                                 Banda Seafood
# 268                            Ikan Bakar Cianjur
# 269                                 Banda Seafood
#
#                                              image_url  sentiment  \
# 0    https://lh5.googleusercontent.com/p/AF1QipPYY3...          0
# 1    https://lh5.googleusercontent.com/p/AF1QipMLaL...          0
# 2    https://lh5.googleusercontent.com/p/AF1QipMcD4...          0
# 3    https://lh5.googleusercontent.com/p/AF1QipPKaD...          0
# 4    https://lh5.googleusercontent.com/p/AF1QipMMDT...          0
# ..                                                 ...        ...
# 265  https://lh5.googleusercontent.com/p/AF1QipOFO-...          2
# 266  https://lh5.googleusercontent.com/p/AF1QipOdZc...          2
# 267  https://lh5.googleusercontent.com/p/AF1QipN1df...          2
# 268  https://lh5.googleusercontent.com/p/AF1QipMJGv...          2
# 269  https://lh5.googleusercontent.com/p/AF1QipMCSq...          2
#
#                                            review_text review_date
# 0    meski buka dengan prokes ketat tempat ini luma...  2021-10-22
# 1    pesan yang catat salah tunggu sangat lama bisa...  2022-05-12
# 2    maaf banget harus kasih bintang tapi jujur kec...  2021-11-12
# 3            gudeg enak kerupuk enak telur enak banget  2017-03-28
# 4    dapat nasi tutuk oncom kasih bonus lalat maaf ...  2021-01-10
# ..                                                 ...         ...
# 265  buat cinta seafood khusus tuna wajib mampir ya...  2021-03-04
# 266  suasana bagus dan asri makan enak ga sempat ng...  2022-11-26
# 267  makan di tempat ini rasa sangat enak yang main...  2022-08-28
# 268  ada bagai macam makan bahan dasar ikan di temp...  2020-01-30
# 269                     makan dan menu mahal dan bobot  2020-01-30
#
# [270 rows x 5 columns]

# %%
# Checking test_df dataframes
test_df
# Out:
#                                            target  \
# 0                         Koenokoeni Cafe Gallery
# 1                           Pesta Keboen Restoran
# 2    Sindang Reret Restaurant & Catering Karawang
# 3                                    Bebek Bengil
# 4                          Gabah Restaurant & Bar
# ..                                            ...
# 265                                 Banda Seafood
# 266                 Seafood Pak Sangklak Semarang
# 267                                 Banda Seafood
# 268                 Seafood Pak Sangklak Semarang
# 269                                    City Extra
#
#                                              image_url  sentiment  \
# 0    https://lh3.googleusercontent.com/a-/ACNPEu-ee...          0
# 1    https://lh3.googleusercontent.com/a-/ACNPEu8iA...          0
# 2    https://lh5.googleusercontent.com/p/AF1QipP4yf...          0
# 3    https://lh5.googleusercontent.com/p/AF1QipP8td...          0
# 4    https://lh5.googleusercontent.com/p/AF1QipPZyg...          0
# ..                                                 ...        ...
# 265  https://lh5.googleusercontent.com/p/AF1QipPHvR...          2
# 266  https://lh5.googleusercontent.com/p/AF1QipMGwD...          2
# 267  https://lh5.googleusercontent.com/p/AF1QipODKF...          2
# 268  https://lh5.googleusercontent.com/p/AF1QipMZIS...          2
# 269  https://lh5.googleusercontent.com/p/AF1QipPPTy...          2
#
#                                            review_text review_date
# 0    pertama kali kesini niat hati ingin jamu tamu ...  2022-06-24
# 1    layan kurang ramah masakan biasa saja tidak pu...  2020-09-15
# 2    restoran sunda turun dan hanya itu cara seluru...  2019-02-21
# 3    bebek krispy dan ga minyak tapi rasa biasa saj...  2022-02-24
# 4    kami dapat batu di makan kami tidak ada kembal...  2018-02-24
# ..                                                 ...         ...
# 265  ini adalah kali pertama bagi saya untuk makan ...  2022-07-04
# 266  restoran seafood yang legendaris di semarang l...  2019-01-24
# 267                   makan enak layan ramah dan cepat  2019-05-23
# 268        enak dan nyaman tempat netral netral netral  2022-06-12
# 269  harga gak terlalu mahal pas makan enak viewnya...  2018-04-23
#
# [270 rows x 5 columns]

# %% [markdown]
# ## Load the Image Captions

# %%
# Load the image captions
with open(captions_json, "r") as f:
  image_captions = json.load(f)

# %%
jumlah_elemen = len(image_captions)
print('Jumlah captions = ',jumlah_elemen)
# Out:
# Jumlah captions =  2698

# %%
# show the image_captions
image_captions
# Out:
# {'https://lh5.googleusercontent.com/p/AF1QipPgsLpuE_LeZ2dppzwSOnUa6CrNWUpB6ncEQB9B': 'sekelompok orang duduk mengelilingi meja makan makanan',
#  'https://lh5.googleusercontent.com/p/AF1QipOiXB35Rr5sDhGbmHYtzLiUwId94TC-Kc6HfmDo': 'meja dan kursi di teras di bawah atap',
#  'https://lh5.googleusercontent.com/p/AF1QipPiO2wZo7YtKY4w1ebhCBbzLHni_jdIs-S_0Ygd': 'seseorang memegang sepiring makanan di tangan mereka',
#  'https://lh5.googleusercontent.com/p/AF1QipOhLMQg9gY6y7gfOL4ABpOp9YC39QIwQcOoNkHS': 'menu untuk restoran Cina di atas meja',
#  'https://lh5.googleusercontent.com/p/AF1Qip
#  'https://lh3.googleusercontent.com/a/ALm5wu2MaiIfe_cQnvqTpwWLFVdoJHm6UMNuedf8xZx9': 'surat putih dengan latar belakang hijau',
#  'https://lh5.googleusercontent.com/p/AF1QipNUYjZIOWLm9BIM_j58pxPeqEKOXD-oiJn3-hvP': 'sekelompok orang duduk mengelilingi meja dengan piring makanan',
#  'https://lh3.googleusercontent.com/a-/ACNPEu8LRwrlLkrpcIjXyG26C1egLCe-fIUVF_7DFvb6': 'seseorang yang memakai topi dan topeng',
#  'https://lh3.googleusercontent.com/a/ALm5wu39KhCOxEVFj3YYF83bw7XQ28ZQxK2GWtho-d-Z': 'huruf putih s dengan latar belakang ungu',
#  'https://lh3.googleusercontent.com/a-/ACNPEu_qHcnm9eokl8JzDcCLAwVI5T7M9Se2NNKzMfZ4V4w': 'seorang wanita mengenakan masker wajah di atas atap',
#  'https://lh3.googleusercontent.com/a/ALm5wu30Dt4dNvu04IcsHUHXRT7m33V-eRuvZkFCDIF5': 'f putih dengan latar belakang hijau',
#  'https://lh3.googleusercontent.com/a-/ACNPEu_XZJ70blqukaq74xf7VpB95_G4E0OqOroZDHvPVw': 'bunga merah duduk di atas meja di samping segelas susu',
#  'https://lh3.googleusercontent.com/a-/ACNPEu-k4MLOVQTUBFo9iiBDbnHsqojd-i2k7bSrW7I-': 'foto hitam putih seorang pria berkaos',
#  'https://lh3.googleusercontent.com/a-/ACNPEu8ioMVbh2YoFZyIwyiPqIY_YbcUAGdmV0KZWOUX9g': 'seorang pria mengambil selfie di depan sebuah gedung',
#  'https://lh5.googleusercontent.com/p/AF1QipOv7A6CjQLoJWoa72ovHbIvm1SbNLDaM5NPZpVV': 'hidran merah duduk di pinggir jalan',
#  'https://lh3.googleusercontent.com/a-/ACNPEu_uqPshcIa-KnAYiPTmCTMQlb3jD2m7eEr4p5niOA': 'seorang pria berbaju merah sedang mengambil selfie',
#  'https://lh5.googleusercontent.com/p/AF1QipO02gOstCg7Vnwh2gBn-eCaYDntKVHdcelP-nxn': 'piring putih di atasnya dengan nasi dan daging',
#  'https://lh5.googleusercontent.com/p/AF1QipNsX1D7M8_0BoWolPowQ8utUFsBvL3NhkGmsDK3': 'mangkuk berisi nasi dan sayuran di atas meja',
#  'https://lh5.googleusercontent.com/p/AF1QipNjkl-aUzl0jlYbqC7iCjgEb5Bkgm4rFzk5GL6x': 'close up makanan dalam mangkuk di atas meja',
#  'https://lh5.googleusercontent.com/p/AF1QipNVMRXfOHKhRiKmo6GVPjdnSxbAivcNjNEAeZHx': 'sekelompok orang duduk di meja dengan piring makanan',
#  'https://lh5.googleusercontent.com/p/AF1QipNfwPUn2BfwN0tSJq908R9gqLnxrgG3m485SbY0': 'piring merah di atasnya dengan sepotong daging yang dilumuri saus',
#  'https://lh5.googleusercontent.com/p/AF1QipNKXduycrMOtE9bgllajIsIjEcEtrWLRscZ3B07': 'sebuah meja dengan dua piring makanan di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipOGJIxVkOw5W5-Hf0LtAgtQixxtVQnylkKEqFO4': 'tampilan dekat piring merah dengan makanan di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipMPzP1C8acT0fNZlyZEeotjnixTkeLoVXH2a22x': 'seorang pria duduk di meja dengan piring makanan',
#  'https://lh5.googleusercontent.com/p/AF1QipNiF8qB4wDPaYOdTqK9unAHtSDjfN0n8OMccULA': 'piring merah dengan makanan di atasnya di sebelah semangkuk sup',
#  'https://lh5.googleusercontent.com/p/AF1Q
atas meja',
#  'https://lh5.googleusercontent.com/p/AF1QipO5nogf62izq-A6ckv-wDDk3hye4cYk0RIEe8kk': 'iklan besar di sisi bangunan',
#  'https://lh5.googleusercontent.com/p/AF1QipN64FNxC6ariiVayzFAfwFViRrAf9zaCNW8pkAQ': 'piring putih atasnya dengan daging dan pasta',
#  'https://lh5.googleusercontent.com/p/AF1QipNjaR5ahTWaX_fd2aWGrC9v7dtgZWUCjnuD7h2D': 'piring putih di atasnya dengan makanan dan sendok',
#  'https://lh5.googleusercontent.com/p/AF1QipOfwZVLt1kSl7br2qbyJ0wd-QO4PlQLrcgNMkq_': 'close up tanda di dinding',
#  'https://lh5.googleusercontent.com/p/AF1QipOuLZh30FOFzaAVNSWzQfgyKIcnqtXPPN5iaKPx': 'sebuah bangunan yang memiliki tanda neon di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipMo0lH8_WKuqNFuGLyUgDYppO7i_whz_Js7KxYC': 'piring putih atasnya dengan daging dan saus',
#  'https://lh5.googleusercontent.com/p/AF1QipOZltkjqmy0GqaQiNQ5TQhgCQ6Rf2fayRWKjv11': 'sebuah ruangan dengan banyak kursi hijau',
#  'https://lh5.googleusercontent.com/p/AF1QipOZLGIi6SN6LEfIv4EzCm3OtIlsW9xHXMAGW3-_': 'piring putih di atasnya dengan makanan di atas meja merah',
#  'https://lh5.googleusercontent.com/p/AF1QipPLppcYB2_FCX8nUjdAJtn6spH4R_HhOHYFlLgo': 'restoran remang-remang dengan meja dan kursi',
#  'https://lh5.googleusercontent.com/p/AF1QipOJXz8NGnriNUzzuQSlfUh5SFiwetrruVlix9gj': 'menu untuk restoran di atas meja',
#  'https://lh5.googleusercontent.com/p/AF1QipPi7EUVn4Pn9c0mfa6K3T2JEHwYRVX-SnvLFHam': 'semangkuk makanan di atas meja dengan sumpit',
#  'https://lh5.googleusercontent.com/p/AF1QipOnz7VdFa6SSSoIMe13xv7PXVBHjTngU7XaN2Q': 'sebuah meja di atasnya dengan mangkuk makanan dan mangkuk sup',
#  'https://lh5.googleusercontent.com/p/AF1QipM28RmLu2TogR0RU5OW60ZjOwAwHSyOo-f3L9a9': 'sebuah meja kayu dengan piring dan mangkuk makanan di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipPTnnmmu7u0FnmvooUocOx32UywEw6xxrsF5gFi': 'sekelompok mobil diparkir di depan sebuah gedung',
#  'https://lh5.googleusercontent.com/p/AF1QipMxFehe5r5p2R8Uc7W7mC0a9Owe0E1Q82lVydM1': 'piring putih atasnya dengan berbagai jenis makanan',
#  'https://lh5.googleusercontent.com/p/AF1QipMjuGGmTc2bj2A5K5oJkznZjjlt2T60l5LPu-mG': 'piring putih di atasnya dengan daging dan sayuran',
#  'https://lh5.googleusercontent.com/p/AF1QipM9ZksbsjVoTuyTLX_xfwRfVUv8BNObgaAFfoLO': 'semangkuk daging sapi dan sayuran dengan sendok',
#  'https://lh5.googleusercontent.com/p/AF1QipMQIkdb8xSw78I2DO1jZwL6c3weHr-eDzGteudZ': 'sepiring makanan dengan udang dan peterseli di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipN4FDbY7vvfWZpiGUlQ3k5erunnA6q7ermhFpTm': 'bangunan yang menyala di malam hari',
#  'https://lh5.googleusercontent.com/p/AF1QipNAGyfC8y43Meog7ETSHil-Z8avJw0BiU-zvBQt': 'sebuah mobil yang diparkir di depan festival kue bulan liburan',
#  'https://lh5.googleusercontent.com/p/AF1QipNjnO9PhOxMcjgeyH4ZztnXo-ptfeAwyAOOvcq3': 'sebuah meja kayu dengan piring-piring makanan di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipMwmSoy8dE7yCEERWIMZmGmJRKibZEoMlsIdNHp': 'semangkuk sup dengan sendok di dalamnya',
#  'https://lh5.googleusercontent.com/p/AF1QipNul9iS-7s2jlfRc_rtbVxSfV0hprP3pUeuwJ7V': 'beberapa minuman yang duduk di atas meja',
#  'https://lh5.googleusercontent.com/p/AF1QipMAc0OJ1efrZxmxbIjNo-zL9M2Bz2vdpsYN5BrV': 'piring putih di atasnya dengan tiga potong makanan',
#  'https://lh5.googleusercontent.com/p/AF1QipOe3paP5R0aEQWeJwREuvRuCXSPrSuFK9nrS6Gw': 'piring putih di atasnya dengan makanan di samping semangkuk sup',
#  'https://lh5.googleusercontent.com/p/AF1QipOuSU2xnsFu7H02icg3LNbNkmF6-PRbciD0T5br': 'meja kayu dengan piring makanan dan sumpit di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipMzM-lWbtu2tQ7g80E1HrY7WYrbyRpbT6TpAdWq': 'semangkuk sup dengan sendok di dalamnya',
#  'https://lh5.googleusercontent.com/p/AF1QipObq8wLaO6CIdzWrr2ho4-H-QZHbWvCbkx2Ur03': 'lorong panjang dengan kursi dan meja',
#  'https://lh5.googleusercontent.com/p/AF1QipPUvpN1O2AnwB0Eyybpcztfp1pFrpnSVJmppQ6U': 'sepiring makanan di atas meja di sebuah restoran',
#  'https://lh5.googleusercontent.com/p/AF1QipOpTx_O4w4tQEihUyqePl31EiY5q2vvra1QQhM3': 'menu untuk restoran di dinding',
#  'https://lh5.googleusercontent.com/p/AF1QipOaj_qrs88tF3870vdr9UKW848_w34HUCYAFzkh': 'mangkuk hijau berisi pasta dan sayuran',
#  'https://lh5.googleusercontent.com/p/AF1QipOhdnO5gIDJsGAmB77KA-qEu_krS3VtdOZmg1tm': 'sebuah meja kayu dengan piring dan mangkuk makanan di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipPfw5SeHO-AXZxSB6VBkko4oeYOzq9DsRhj5RmX': 'piring biru dengan dua pangsit di atasnya di atas meja kayu',
#  'https://lh5.googleusercontent.com/p/AF1QipNbAjWUwvXIShC9BBRT4PVZrAq9IiIOhNbdEFWb': 'sebuah bar dengan banyak botol di atasnya',
#  'https://lh5.googleusercontent.com/p/AF1QipPXDdLRzDztukMoJDE3WxNbHGHrnprkuyBs3f4P': 'dua menu di dinding sebuah restoran',
#  'https://lh5.googleusercontent.com/p/AF1QipNgugZ0aXTGFMC83suy4yfiMeHEIVKVen1wEF1u': 'piring putih atasnya dengan daging dan saus',
#  ...}

# %% [markdown]
# ## Build Language Model

# %%
# Instantiate the Tokenizer
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %% [markdown]
# ## Construct the Dataset

# %%
# # Construct the dataset.
# class RestaurantReviewDataset(Dataset):
#     def __init__(
#         self,
#         reviews: np.array,
#         labels: np.array,
#         sentiment_targets: np.array,
#         image_urls: np.array,
#         review_date : np.array,
#         # image_captions,
#         tokenizer,
#         max_len: int,
#     ):
#         """
#         Downstream code expects reviews and targets to be NumPy arrays.
#         """
#         self.reviews = reviews
#         self.labels = labels
#         self.tokenizer = tokenizer
#         self.sentiment_targets = sentiment_targets
#         # self.image_captions = image_captions
#         self.max_len = max_len
#         self.image_urls = image_urls
#         self.review_date = review_date

#     def __len__(self):
#         return len(self.reviews)

#     def __getitem__(self, item):
#         review = str(self.reviews[item])
#         label = self.labels[item]
#         sentiment_target = self.sentiment_targets[item]
#         # try:
#         #     caption = self.image_captions[self.image_ids[item]]
#         # except KeyError:  # A couple of the images have no content.
#         #     caption = ""

#         encoding = self.tokenizer.encode_plus(
#             review,
#             # text_pair=sentiment_target + "." + caption,
#             add_special_tokens=True,
#             max_length=self.max_len,
#             return_token_type_ids=False,
#             padding="max_length",
#             return_attention_mask=True,
#             return_tensors="pt",
#             truncation=True,
#         )

#         return {
#             "review_text": review,
#             "sentiment_targets": sentiment_target,
#             # "caption": caption,
#             "input_ids": encoding["input_ids"].flatten(),
#             "attention_mask": encoding["attention_mask"].flatten(),
#             "targets": torch.tensor(label, dtype=torch.long),
#         }

# %%
# Construct the dataset.
class RestaurantReviewDataset(Dataset):
    def __init__(
        self,
        reviews: np.array,
        labels: np.array,
        sentiment_targets: np.array,
        image_urls: np.array,
        review_date : np.array,
        image_captions,
        tokenizer,
        max_len: int,
    ):
        """
        Downstream code expects reviews and targets to be NumPy arrays.
        """
        self.reviews = reviews
        self.labels = labels
        self.tokenizer = tokenizer
        self.sentiment_targets = sentiment_targets
        self.image_captions = image_captions
        self.max_len = max_len
        self.image_urls = image_urls
        self.review_date = review_date

    def __len__(self):
        return len(self.reviews)

    def __getitem__(self, item):
        review = str(self.reviews[item])
        label = self.labels[item]
        sentiment_target = self.sentiment_targets[item]
        try:
            caption = self.image_captions[self.image_urls[item]]
        except KeyError:  # A couple of the images have no content.
            caption = ""

        encoding = self.tokenizer.encode_plus(
            review,
            text_pair=caption,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding="max_length",
            return_attention_mask=True,
            return_tensors="pt",
            truncation=True,
        )

        return {
            "review_text": review,
            "sentiment_targets": sentiment_target,
            "caption": caption,
            "input_ids": encoding["input_ids"].flatten(),
            "attention_mask": encoding["attention_mask"].flatten(),
            "targets": torch.tensor(label, dtype=torch.long),
        }

# %% [markdown]
# ## Construct the Data Loader

# %%
# # Construct the data loaders.
# def create_data_loader(df, tokenizer, max_len, batch_size, image_captions):
#   ds = RestaurantReviewDataset(
#       reviews = df.review_text.to_numpy(),
#       labels = df.sentiment.to_numpy(),
#       sentiment_targets = df.target.to_numpy(),
#       image_urls = df.image_url.to_numpy(),
#       # image_captions = image_captions,
#       tokenizer = tokenizer,
#       max_len = max_len,
#   )
#   return DataLoader(ds, batch_size = batch_size, num_workers=2)

#   train_data_loader = create_data_loader(
#       train_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
#   )

#   val_data_loader = create_data_loader(
#       val_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
#   )

#   test_data_loader = create_data_loader(
#       test_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
#   )

# %%
# # Construct the data loaders.
# def create_data_loader(df, tokenizer, max_len, batch_size):
#   ds = RestaurantReviewDataset(
#       reviews = df.review_text.to_numpy(),
#       labels = df.sentiment.to_numpy(),
#       sentiment_targets = df.target.to_numpy(),
#       image_urls = df.image_url.to_numpy(),
#       review_date = df.review_date.to_numpy(),
#       # image_captions = image_captions,
#       tokenizer = tokenizer,
#       max_len = max_len,
#   )
#   return DataLoader(ds, batch_size = batch_size, num_workers=2)

# train_data_loader = create_data_loader(
#     train_df, tokenizer, MAX_LEN, BATCH_SIZE
# )

# val_data_loader = create_data_loader(
#     val_df, tokenizer, MAX_LEN, BATCH_SIZE
# )

# test_data_loader = create_data_loader(
#     test_df, tokenizer, MAX_LEN, BATCH_SIZE
# )

# %%
# Construct the data loaders.
def create_data_loader(df, tokenizer, max_len, batch_size, image_captions):
  ds = RestaurantReviewDataset(
      reviews = df.review_text.to_numpy(),
      labels = df.sentiment.to_numpy(),
      sentiment_targets = df.target.to_numpy(),
      image_urls = df.image_url.to_numpy(),
      review_date = df.review_date.to_numpy(),
      image_captions = image_captions,
      tokenizer = tokenizer,
      max_len = max_len,
  )
  return DataLoader(ds, batch_size = batch_size, num_workers=2)

train_data_loader = create_data_loader(
    train_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
)

val_data_loader = create_data_loader(
    val_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
)

test_data_loader = create_data_loader(
    test_df, tokenizer, MAX_LEN, BATCH_SIZE, image_captions
)

# %%
train_data_loader

# %%
val_data_loader

# %%
test_data_loader

# %% [markdown]
# ## Construct and Instantiate the Classifier

# %%
# Construct and instantiate the classifier.
class SentimentClassifier(nn.Module):
  def __init__(self, n_classes):
    super(SentimentClassifier, self).__init__()
    self.bert = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)
    self.drop = nn.Dropout(p=DROPOUT_PROB)
    self.out = nn.Linear(self.bert.config.hidden_size, n_classes)
  
  def forward(self, input_ids, attention_mask):
    outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
    outputs = self.drop(outputs.pooler_output)
    return self.out(outputs)

# %% [markdown]
# ## Set up the device

# %%
# Set up the device
if torch.cuda.is_available():
  device = torch.device(DEVICE)
  print(f"Using {DEVICE}.")
else:
  device = torch.device("cpu")
  print(f"CUDA not available, using CPU.")
# Out:
# Using cuda:1.

# %% [markdown]
# ## Define train_method : train_epochs

# %%
def train_epoch(model, data_loader, loss_fn, optimizer, device, scheduler, n_examples):
  model = model.train()

  losses = []
  correct_predictions = 0

  for d in data_loader:
    input_ids = d["input_ids"].to(device="cuda:0")
    attention_mask = d["attention_mask"].to(device="cuda:0")
    targets = d["targets"].to(device="cuda:0")

    outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    _, preds = torch.max(outputs, dim=1)
    loss = loss_fn(outputs, targets)

    correct_predictions += torch.sum(preds == targets).item()
    losses.append(loss.item())

    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
  return correct_predictions / n_examples, np.mean(losses)

# %% [markdown]
# ## Define format output method : format_eval_method

# %%
def format_eval_output(rows):
  reviews, targets, labels, predictions = zip(*rows)
  reviews = np.vstack(reviews)
  targets = np.vstack(targets)
  labels = np.vstack(labels)
  predictions = np.vstack(predictions)
  results_df = pd.DataFrame()
  results_df["review"] = reviews.reshape(-1).tolist()
  results_df["target"] = targets.reshape(-1).tolist()
  results_df["label"] = labels
  results_df["prediction"] = predictions
  return results_df

# %% [markdown]
# ## Define model : eval model

# %%
def eval_model(model, data_loader, loss_fn, device, n_examples, detailed_results=False):
  model = model.eval()

  losses = []
  correct_predictions = 0
  rows = []

  with torch.no_grad():
    for d in data_loader:
      input_ids = d["input_ids"].to(device="cuda:0")
      attention_mask = d["attention_mask"].to(device="cuda:0")
      targets = d["targets"].to(device="cuda:0")

      outputs = model(input_ids=input_ids, attention_mask=attention_mask)

      _, preds = torch.max(outputs, dim=1)
      loss = loss_fn(outputs, targets)

      correct_predictions += torch.sum(preds==targets).item()
      losses.append(loss.item())
      rows.extend(
          zip(
              d["review_text"],
              d["sentiment_targets"],
              d["targets"].numpy(),
              preds.cpu().numpy(),
          )
      )

    if detailed_results:
      return(
          correct_predictions/n_examples,
          np.mean(losses),
          format_eval_output(rows),
      )
  return correct_predictions/n_examples, np.mean(losses)

# %% [markdown]
# ## Fitting the Model

# %%
results_per_run = {}
results_training_per_run = {}
counter = 0
list_train_accuracy = []
list_train_loss = []
list_val_accuracy = []
list_val_loss = []
for run_number in range(NUM_RUNS):
  # np.random.seed(RANDOM_SEEDS[run_number])
  # torch.manual_seed(RANDOM_SEEDS[run_number])

  # Setup the model, test it with a single batch.
  data = next(iter(train_data_loader))
  model = SentimentClassifier(NUM_CLASSES)
  model.to(device="cuda:0")
  input_ids = data["attention_mask"].to(device="cuda:0")
  attention_mask = data["attention_mask"].to(device="cuda:0")
  model(input_ids, attention_mask)

  # Configure the Optimizer and scheduler.
  optimizer = AdamW(model.parameters(), lr=LEARNING_RATE, correct_bias=ADAMW_CORRECT_BIAS)
  total_steps = len(train_data_loader) * EPOCHS
  scheduler = get_linear_schedule_with_warmup(
      optimizer, num_warmup_steps=NUM_WARMUP_STEPS, num_training_steps=total_steps
  )
  loss_fn = nn.CrossEntropyLoss().to(device="cuda:0")

  for epoch in range(EPOCHS):
    counter += 1
    print(f"Epoch {epoch+1}/{EPOCHS} -- RUN {run_number}")
    print("-"*10)
    train_acc, train_loss = train_epoch(
        model, train_data_loader, loss_fn, optimizer, device, scheduler, len(train_df)
    )
    print(f"Train loss {train_loss} accuracy {train_acc}")
    
    val_acc, val_loss = eval_model(model, val_data_loader, loss_fn, device, len(val_df))
    print(f"Val loss {val_loss} accuracy {val_acc}")
    results_training_per_run[counter] = {
        'train_accuracy' : train_acc,
        'train_loss' : train_loss,
        'val_accuracy' : val_acc,
        'val_loss' : val_loss
    }
  
  test_acc, _, detailed_results = eval_model(
      model, test_data_loader, loss_fn, device, len(test_df), detailed_results=True
  )

  macro_f1 = f1_score(
      detailed_results.label, detailed_results.prediction, average="macro"
  )
  print(f"TEST ACC = {test_acc}\nMACRO F1 = {macro_f1}")

  results_per_run[run_number] = {
      'accuracy' : test_acc,
      'macro-f1' : macro_f1
  }
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/672M [00:00<?, ?B/s]
# Epoch 1/10 -- RUN 0
# ----------
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Train loss 1.1602892822689481 accuracy 0.31666666666666665
# Val loss 1.0979225635528564 accuracy 0.34074074074074073
# Epoch 2/10 -- RUN 0
# ----------
# Train loss 1.1202933664675112 accuracy 0.3101851851851852
# Val loss 1.0935924754423254 accuracy 0.34074074074074073
# Epoch 3/10 -- RUN 0
# ----------
# Train loss 1.1100365047101621 accuracy 0.33055555555555555
# Val loss 1.0580692396444433 accuracy 0.4777777777777778
# Epoch 4/10 -- RUN 0
# ----------
# Train loss 1.0637911800984983 accuracy 0.4300925925925926
# Val loss 0.9420818721546846 accuracy 0.5296296296296297
# Epoch 5/10 -- RUN 0
# ----------
# Train loss 0.9467894320134763 accuracy 0.5305555555555556
# Val loss 0.9057751893997192 accuracy 0.5740740740740741
# Epoch 6/10 -- RUN 0
# ----------
# Train loss 0.8532879827199159 accuracy 0.5879629629629629
# Val loss 0.8701214790344238 accuracy 0.6074074074074074
# Epoch 7/10 -- RUN 0
# ----------
# Train loss 0.7452992022037506 accuracy 0.6666666666666666
# Val loss 0.9332791724625755 accuracy 0.5703703703703704
# Epoch 8/10 -- RUN 0
# ----------
# Train loss 0.669542999179275 accuracy 0.7138888888888889
# Val loss 0.9017425863181844 accuracy 0.5925925925925926
# Epoch 9/10 -- RUN 0
# ----------
# Train loss 0.6006130594898154 accuracy 0.762962962962963
# Val loss 0.8888190108187058 accuracy 0.6185185185185185
# Epoch 10/10 -- RUN 0
# ----------
# Train loss 0.5588141636715995 accuracy 0.7805555555555556
# Val loss 0.8931979887625751 accuracy 0.6148148148148148
# TEST ACC = 0.6592592592592592
# MACRO F1 = 0.648323702240753

# %%
path_result_test_file = './' + result_test_file_name
with open(path_result_test_file, 'w+') as f:
  json.dump(results_per_run, f)


print(f"AVERAGE ACC = {np.mean([_['accuracy'] for _ in results_per_run.values()])}")
print(f"AVERAGE MAC-F1 = {np.mean([_['macro-f1'] for _ in results_per_run.values()])}")
# Out:
# AVERAGE ACC = 0.6592592592592592
# AVERAGE MAC-F1 = 0.648323702240753

# %%
path_result_train_file = './' + result_train_file_name
with open(path_result_train_file, 'w+') as f:
  json.dump(results_training_per_run, f)
  

print(f"AVERAGE ACC = {np.mean([_['accuracy'] for _ in results_per_run.values()])}")
print(f"AVERAGE MAC-F1 = {np.mean([_['macro-f1'] for _ in results_per_run.values()])}")
# Out:
# AVERAGE ACC = 0.6592592592592592
# AVERAGE MAC-F1 = 0.648323702240753

# %%
# For download files in colab local directory
from google.colab import files
# name_file = 'results_per_run.json'
files.download(result_test_file_name)
files.download(result_train_file_name)

# %% [markdown]
# ## Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
# from sklearn.metrics import confusion_matrix, plot_confusion_matrix

# %%
class_names = ['Negative', 'Neutral', 'Positive']

# %%
cm = confusion_matrix(detailed_results.label, detailed_results.prediction)

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['negative', 'neutral', 'positive'], yticklabels=['negative', 'neutral', 'positive'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Sentiment")
plt.ylabel("True Sentiment")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['negative', 'neutral', 'positive'], yticklabels=['negative', 'neutral', 'positive'])
plt.title("Confusion Matrix Model Terbaik Skenario 3")
plt.xlabel("Predicted Sentiment")
plt.ylabel("True Sentiment")
plt.show()

# %% [markdown]
# ## Classification Report

# %%
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(detailed_results.label, detailed_results.prediction)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73        92
#            1       0.58      0.42      0.49        90
#            2       0.66      0.81      0.72        88
#
#     accuracy                           0.66       270
#    macro avg       0.65      0.66      0.65       270
# weighted avg       0.65      0.66      0.65       270

# %%
target_names = ['negative', 'neutral', 'positive']
report = classification_report(detailed_results.label, detailed_results.prediction, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.75      0.73        92
#      neutral       0.58      0.42      0.49        90
#     positive       0.66      0.81      0.72        88
#
#     accuracy                           0.66       270
#    macro avg       0.65      0.66      0.65       270
# weighted avg       0.65      0.66      0.65       270

# %% [markdown]
# ## Plot Train Accuracy and Validation Accuracy

# %%
epochs = list(results_training_per_run.keys())
train_accuracy = [results_training_per_run[epoch]["train_accuracy"] for epoch in epochs]
val_accuracy = [results_training_per_run[epoch]["val_accuracy"] for epoch in epochs]

# %%
plt.title("Grafik Perbandingan Akurasi Latih dan Akurasi Validasi Model Terbaik Skenario 3")
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
# Menambahkan garis putus pada sumbu x dan y
# plt.axhline(0, linestyle='dashed', color='gray', linewidth=0.5)
# plt.axvline(0, linestyle='dashed', color='gray', linewidth=0.5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.title("Grafik Perbandingan Train Accuracy dan Validation Accuracy Model Terbaik Skenario 3")
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Plot Train Loss and Validation Loss

# %%
epochs = list(results_training_per_run.keys())
train_loss = [results_training_per_run[epoch]["train_loss"] for epoch in epochs]
val_loss = [results_training_per_run[epoch]["val_loss"] for epoch in epochs]

# %%
plt.title("Grafik Perbandingan Loss Latih dan Loss Validasi Model Terbaik Skenario 3")
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.title("Grafik Perbandingan Train Loss dan Validation Loss Model Terbaik Skenario 3")
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model to My Drive

# %%
# Simpan model
torch.save(model.state_dict(), model_name)

# %%
# model_name = "trained_model.pth"
files.download(model_name)

# %%
# !pip install PyDrive

# %%
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive

# gauth = GoogleAuth()
# drive = GoogleDrive(gauth)

# %%
# gauth.LocalWebserverAuth()

# %%
# folder_name = 'Best_Model_Skripsi_Risma'
# folder_id = None

# # Cari ID folder dengan nama "Best_Model_Skripsi_Risma"
# folder_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
# for folder in folder_list:
#     if folder['title'] == folder_name:
#         folder_id = folder['id']
#         break

# print("ID Folder:", folder_id)

# %%
# file_path = 'trained_model.pth'  # Ganti dengan path file yang ingin diunggah
# file_title = 'trained_model_MultiligualBERT.pth'  # Ganti dengan nama file yang diinginkan pada Google Drive

# # Unggah file ke folder "Best_Model_Skripsi_Risma"
# file = drive.CreateFile({'title': file_title, 'parents': [{'id': folder_id}]})
# file.SetContentFile(file_path)
# file.Upload()

# %%
# # Import library yang dibutuhkan
# from google.colab import files

# # Pilih file yang akan disimpan ke Google Drive
# uploaded = files.upload()
# # path_file = '/content/drive/My Drive/<nama_folder>/<nama_file>'

# # Simpan file ke Google Drive
# for filename in uploaded.keys():
#   with open(path_file_drive, 'wb') as f:
#     f.write(uploaded[filename])
#     print(f"File '{filename}' berhasil disimpan ke Google Drive!")

# %%
# # confusionmat_csv_file = '/content/drive/My Drive/Penelitian/ep20lr0003m09confusionmat_xception_100.csv'
# path_file_drive = 'content/drive/My Drive/Bismillah_Skripsi_Bisa_Amiiin/Running/coba/' + result_file_name
# with open(path_file_drive, mode='w') as f:
#     f.write(path_result_file)

# %%
print('Hello WOrld!')
# Out:
# Hello WOrld!

# %%
print('Risma Keren!')
# Out:
# Risma Keren!

# %%
print('Risma Baik ^-^')
# Out:
# Risma Baik ^-^
